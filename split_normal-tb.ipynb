# %%
import pandas as pd

# %%
test_data =pd.read_csv('alldata/test_metadata.csv')
train_data = pd.read_csv('alldata/train_metadata.csv')

# %%
test_data
# Out:
#             Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 0      00030606_004.png     No Finding            4       30606           58
# 1      00008522_001.png     No Finding            1        8522           60
# 2      00015556_012.png     No Finding           12       15556           56
# 3      00009215_002.png     No Finding            2        9215           40
# 4      00020591_000.png     No Finding            0       20591           68
# ...                 ...            ...          ...         ...          ...
# 12132  00005740_000.png     No Finding            0        5740           44
# 12133  00013956_000.png     No Finding            0       13956           54
# 12134  00012171_001.png     No Finding            1       12171           36
# 12135  00011674_001.png     No Finding            1       11674           19
# 12136  00011379_020.png     No Finding           21       11379            9
#
# ...

# %%
pneu_test_data = test_data.loc[test_data['target']==1]
pneu_test_data.to_csv('alldata/pneu_test_metadata.csv',index=False)

# %%
norm_test_data = test_data.loc[test_data['target']==0]
norm_test_data.to_csv('alldata/norm_test_metadata.csv',index=False)
norm_test_data
# Out:
#             Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 0      00030606_004.png     No Finding            4       30606           58
# 1      00008522_001.png     No Finding            1        8522           60
# 2      00015556_012.png     No Finding           12       15556           56
# 3      00009215_002.png     No Finding            2        9215           40
# 4      00020591_000.png     No Finding            0       20591           68
# ...                 ...            ...          ...         ...          ...
# 12132  00005740_000.png     No Finding            0        5740           44
# 12133  00013956_000.png     No Finding            0       13956           54
# 12134  00012171_001.png     No Finding            1       12171           36
# 12135  00011674_001.png     No Finding            1       11674           19
# 12136  00011379_020.png     No Finding           21       11379            9
#
# ...

# %%
pneu_train_data = train_data.loc[train_data['target']==1]
pneu_train_data.to_csv('alldata/pneu_train_metadata.csv',index=False)
pneu_train_data
# Out:
#             Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 98     00018996_002.png      Pneumonia            2       18996           21
# 277    00014405_001.png      Pneumonia            1       14405           32
# 465    00018843_000.png      Pneumonia            0       18843           50
# 742    00013625_069.png      Pneumonia           69       13625           65
# 757    00021201_037.png      Pneumonia           37       21201           65
# ...                 ...            ...          ...         ...          ...
# 48057  00012733_000.png      Pneumonia            5       12733           73
# 48129  00001637_001.png      Pneumonia           11        1637           22
# 48202  00026179_003.png      Pneumonia            3       26179           26
# 48301  00011973_015.png      Pneumonia           12       11973           62
# 48344  00005639_003.png      Pneumonia            1        5639           22
#
# ...

# %%
norm_train_data = train_data.loc[train_data['target']==0]
norm_train_data.to_csv('alldata/norm_train_metadata.csv',index=False)
norm_train_data
# Out:
#             Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 0      00027799_001.png     No Finding            1       27799           25
# 1      00022997_000.png     No Finding            0       22997           61
# 2      00019021_004.png     No Finding            4       19021           44
# 3      00020468_000.png     No Finding            0       20468           53
# 4      00013829_007.png     No Finding            7       13829           33
# ...                 ...            ...          ...         ...          ...
# 48541  00001809_000.png     No Finding            0        1809           47
# 48542  00008492_000.png     No Finding            0        8492           63
# 48543  00021285_009.png     No Finding            9       21285           66
# 48544  00027299_003.png     No Finding            3       27299           28
# 48545  00029599_001.png     No Finding            1       29599           57
#
# ...
